# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### Generate some sample data for demostration

# %%
np.random.seed(0)

# %%
X = 2* np.random.rand(100,1) # Independent variable

# %%
Y = 4+3*X+np.random.randn(100,1) # Dependent variable with noise

# %%
#Create a Linear Regression model

# %%
model = LinearRegression()

# %%
#

# %%
model.fit(X,Y)
# Out:
# LinearRegression()

# %%
# Make prediction

# %%
X_new = np.array([[0],[2]])

# %%
Y_pred = model.predict(X_new)

# %%
# Plot the data and the regression line

# %%
plt.scatter(X, Y, label="Sample Data")
plt.plot(X_new,Y_pred, 'r-', label='Linear Regression')
plt.xlabel('Independent Variable')
plt.ylabel('Dependent Variable')
plt.legend()
plt.title('Linear Regression Example')
plt.show()

# %%
print(f'Intercept (b0): {model.intercept_}')
# Out:
# Intercept (b0): [4.22215108]

# %%
print(f'Coeffient (b1): {model.coef_}')
# Out:
# Coeffient (b1): [[2.96846751]]
